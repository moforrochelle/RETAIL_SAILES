# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the datasets
df = pd.read_csv('retail_sales copy.csv')
df
# Out:
#      TransactionID        Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001  2023-07-11    S003      P001         4       1496
# 1            T0002  2023-10-04    S004      P002         2       1069
# 2            T0003  2023-06-10    S005      P019         1        966
# 3            T0004  2023-11-10    S002      P014         5        488
# 4            T0005  2023-01-22    S003      P020         3       1065
# ...            ...         ...     ...       ...       ...        ...
# 4995         T4996  2023-06-15    S004      P007         5        190
# 4996         T4997  2023-12-10    S002      P010         2        944
# 4997         T4998  2023-10-05    S005      P015         2        455
# 4998         T4999  2023-05-10    S001      P012         5        342
# 4999         T5000  2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory
# 0          C271          Cash         Printer
# ...

# %%
# printing the 1st 10 rows of the dataset
df.head(10)
# Out:
#   TransactionID        Date StoreID ProductID  Quantity  UnitPrice CustomerID  \
# 0         T0001  2023-07-11    S003      P001         4       1496       C271
# 1         T0002  2023-10-04    S004      P002         2       1069       C305
# 2         T0003  2023-06-10    S005      P019         1        966       C391
# 3         T0004  2023-11-10    S002      P014         5        488       C211
# 4         T0005  2023-01-22    S003      P020         3       1065       C168
# 5         T0006  2023-09-10    S004      P010         4       1130       C283
# 6         T0007  2023-08-24    S004      P009         2        547       C296
# 7         T0008  2023-12-11    S001      P010         1        218       C226
# 8         T0009  2023-02-18    S001      P006         1       1038       C275
# 9         T0010  2023-02-28    S002      P017         5        610       C362
#
#   PaymentMethod ProductCategory
# 0          Cash         Printer
# 1          Card      Headphones
# ...

# %%
# printing the column names
df.columns
# Out:
# Index(['TransactionID', 'Date', 'StoreID', 'ProductID', 'Quantity',
#        'UnitPrice', 'CustomerID', 'PaymentMethod', 'ProductCategory'],
#       dtype='object')

# %%
# printing the shape of the dataset
df.shape
# Out:
# (5000, 9)

# %%
# checking for missing values in the dataset
missing_values = df.isnull().sum()
missing_values
# Out:
# TransactionID      0
# Date               0
# StoreID            0
# ProductID          0
# Quantity           0
# UnitPrice          0
# CustomerID         0
# PaymentMethod      0
# ProductCategory    0
# dtype: int64

# %%
# checking for duplicates in the dataset
duplicates_values = df.duplicated().sum()
duplicates_values
# Out:
# np.int64(0)

# %%
#filling the missing values
df.ffill()
# Out:
#      TransactionID        Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001  2023-07-11    S003      P001         4       1496
# 1            T0002  2023-10-04    S004      P002         2       1069
# 2            T0003  2023-06-10    S005      P019         1        966
# 3            T0004  2023-11-10    S002      P014         5        488
# 4            T0005  2023-01-22    S003      P020         3       1065
# ...            ...         ...     ...       ...       ...        ...
# 4995         T4996  2023-06-15    S004      P007         5        190
# 4996         T4997  2023-12-10    S002      P010         2        944
# 4997         T4998  2023-10-05    S005      P015         2        455
# 4998         T4999  2023-05-10    S001      P012         5        342
# 4999         T5000  2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory
# 0          C271          Cash         Printer
# ...

# %%
# converting the date to date time object
df['Date'] = pd.to_datetime(df['Date'],format='mixed')
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory
# 0          C271          Cash         Printer
# ...

# %%
#ensuring that the Quantity and UnitPrice are numeric 
df['Quantity'] = pd.to_numeric(df['Quantity'])
df['UnitPrice'] = pd.to_numeric(df['UnitPrice'])
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory
# 0          C271          Cash         Printer
# ...

# %%
# getting the Total Price using numpy vectorisation
df['Total Price'] = df['Quantity'].values * df['UnitPrice'].values
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory  Total Price
# 0          C271          Cash         Printer         5984
# ...

# %%
#extracting the year
df['Year'] = df['Date'].dt.year
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory  Total Price  Year
# 0          C271          Cash         Printer         5984  2023
# ...

# %%
#extracting the momth
df['Month'] = df['Date'].dt.month
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory  Total Price  Year  Month
# ...

# %%
#extracting the day of the week
df['Day of the week'] = df['Date'].dt.day_of_week
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory  Total Price  Year  Month  \
# ...

# %%
# checking if the transaction was carried out on a weekday or on a weekend
df['IsWeekend'] = df['Day of the week']>=5
df
# Out:
#      TransactionID       Date StoreID ProductID  Quantity  UnitPrice  \
# 0            T0001 2023-07-11    S003      P001         4       1496
# 1            T0002 2023-10-04    S004      P002         2       1069
# 2            T0003 2023-06-10    S005      P019         1        966
# 3            T0004 2023-11-10    S002      P014         5        488
# 4            T0005 2023-01-22    S003      P020         3       1065
# ...            ...        ...     ...       ...       ...        ...
# 4995         T4996 2023-06-15    S004      P007         5        190
# 4996         T4997 2023-12-10    S002      P010         2        944
# 4997         T4998 2023-10-05    S005      P015         2        455
# 4998         T4999 2023-05-10    S001      P012         5        342
# 4999         T5000 2023-01-31    S001      P001         1       1104
#
#      CustomerID PaymentMethod ProductCategory  Total Price  Year  Month  \
# ...

# %%
# checking the total sales for the year
total_sales_by_year = df.groupby('Year')['Total Price'].sum()
total_sales_by_year
# Out:
# Year
# 2023    11706475
# Name: Total Price, dtype: int64

# %%
# identifying the top 5 best selling products
product_sales = df.groupby('ProductCategory')['Total Price'].sum()
product_sales
# Out:
# ProductCategory
# Camera        1259526
# Headphones    1038963
# Monitor       2963723
# Mouse          637084
# Printer       1726854
# Smartphone    1159387
# Smartwatch    1776777
# Tablet        1144161
# Name: Total Price, dtype: int64

# %%
top_5_products = product_sales.nlargest(5)
top_5_products
# Out:
# ProductCategory
# Monitor       2963723
# Smartwatch    1776777
# Printer       1726854
# Camera        1259526
# Smartphone    1159387
# Name: Total Price, dtype: int64

# %%
# identifying the month that had the highest sales( month 4 is April)
monthly_sales = df.groupby('Month')['Total Price'].sum()
print (monthly_sales)
highest_month_sales = monthly_sales.idxmax()
highest_amount_sales = monthly_sales.max()
print(f"The month with the highest sales was {highest_month_sales} with sales of {highest_amount_sales}")
# Out:
# Month
# 1      958251
# 2      989773
# 3      966895
# 4     1055991
# 5      970694
# 6     1030989
# 7      862586
# 8      991163
# 9      969976
# 10     973451
# 11     922727
# 12    1013979
# Name: Total Price, dtype: int64
# The month with the highest sales was 4 with sales of 1055991

# %%
#identifying the most common payment method
Payment_method = df['PaymentMethod'].value_counts()
most_common_payment_method = Payment_method.index[0]
most_common_payment_method
# Out:
# 'Online'

# %%
# calculating the order average value per store
df['Total Price'] = df['Quantity']* df['UnitPrice']
order_values = df.groupby('ProductID')['Total Price'].sum().reset_index

# %%
#creating a line plot for monthly sales
plt.plot(monthly_sales.index, monthly_sales.values, linestyle = '-', color = 'g')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Price')
plt.show()

# %%
#a bar chart showing the top 5 products by revenue
product_sales = df.groupby('ProductCategory')['Total Price'].sum()
product_sales
top_5_products = product_sales.nlargest(5)
top_5_products
plt.bar(top_5_products.index ,top_5_products.values, color = 'green')
# Out:
# <BarContainer object of 5 artists>

# %%
# creating a pie chart for sales distribution by payment method
sales_by_payment = df.groupby('PaymentMethod')['Total Price'].sum()
labels = sales_by_payment.index
sizes = sales_by_payment.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Sales Distribution by PaymentMethod')
plt.axis('equal')
plt.show()

# %%
# a histogram for distribution of order values
df['Totalvalue'] = df['Quantity']* df['UnitPrice']
order_values = df.groupby('ProductID')['Totalvalue'].sum()
plt.hist(order_values , bins=28, edgecolor='pink')
plt.xlabel('order_values')
plt.ylabel('number of orders')
plt.title('Distribution of order values')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# plotting a grouped bar chartfor the monthly sales per store
monthly_store_sales = df.groupby(["StoreID", "Month"])["Total Price"].sum().unstack()
monthly_store_sales.plot(kind='bar', figsize=(12,6))
plt.title("Monthly Sales per Store")
plt.xlabel("Store")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.legend(title="Month")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # INSIGHTS ON THE RETAIL_SALES DATASET
# * Most of the purchases were done on weekdays and few on weekends
# * Most of the customers purchased goods online and payed online meaning online is a high-purchasing and paying channel for customers
# * In the year 2023 most of the goods purchased were goods with lower unit prices with the monitor being the most highly purchased good

# %% [markdown]
# # 2 business actions based on the data
# * Offering different payment methods like mobile wallets,BOPIS(buy online and pick up in store)
# * Providing effective sales training and ensuring that the store(business)shows up in the online search results since most customers pay online
